# %% [markdown]
# ## Importing Libraries and Setup

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# creating path variable
path = r'/Users/paigepearson/Desktop/Data Analytics/Immersion Course/Achievement 6/Boat Dashboard'

# %%
# make sure charts are shown in notebook
# %matplotlib inline

# %%
# Setting the stying of the Seaborn figure
sns.set_style('darkgrid')

# %%
# importing data
mini_boat = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'numerical_subset_no_outliers.csv'))

# %%
# checking work
mini_boat.head()
# Out:
#    Unnamed: 0  Price in EUR  Year Built  Length  Width  Views
# 0           0          3476        2017    4.00   1.90    226
# 1           1          3490        2020    4.00   1.50     75
# 2           2          3472        2020    3.00   1.00     64
# 3           3          3399        2019    3.55   1.46     58
# 4           4          3750        1999    6.20   2.38    474

# %%
# removing Unnamed column that sometimes pops up
mini_boat = mini_boat.drop(columns = 'Unnamed: 0')

# %%
# checking work
mini_boat.head()
# Out:
#    Price in EUR  Year Built  Length  Width  Views
# 0          3476        2017    4.00   1.90    226
# 1          3490        2020    4.00   1.50     75
# 2          3472        2020    3.00   1.00     64
# 3          3399        2019    3.55   1.46     58
# 4          3750        1999    6.20   2.38    474

# %% [markdown]
# ## Recreating Charts

# %%
# creating a correlation matrix heatmap using seaborn

# creating a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# creating the correlation heatmap in seaborn 
corr = sns.heatmap(mini_boat.corr(), annot = True, ax = ax)

# %%
# create pairplot
pairplot = sns.pairplot(mini_boat, 
                       kind='reg', 
                       diag_kind='kde', 
                       plot_kws={'color':'darkslateblue', 'line_kws':{'color':'tomato'}}, 
                       diag_kws={'color':'black'})
# Out:
# /Users/paigepearson/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# creating scatterplot of 'Price in EUR' and 'Length'
scatter_price_length = sns.lmplot(x='Price in EUR', y='Length', data=mini_boat, scatter_kws={'color': 'purple'})

# setting axis labels
plt.xlabel('Price in Euros by Million')
plt.ylabel('Length by Meters')
plt.xticks([0, 500000, 1000000, 1500000, 2000000, 2500000, 3000000, 3500000], ['0', '0.5', '1', '1.5', '2', '2.5', '3', '3.5'])
# Out:
# /Users/paigepearson/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ([<matplotlib.axis.XTick at 0x173684510>,
#   <matplotlib.axis.XTick at 0x1736e5850>,
#   <matplotlib.axis.XTick at 0x173583110>,
#   <matplotlib.axis.XTick at 0x17402a790>,
#   <matplotlib.axis.XTick at 0x1740347d0>,
#   <matplotlib.axis.XTick at 0x174036b10>,
#   <matplotlib.axis.XTick at 0x1736e7c10>,
#   <matplotlib.axis.XTick at 0x174051550>],
#  [Text(0, 0, '0'),
#   Text(500000, 0, '0.5'),
#   Text(1000000, 0, '1'),
#   Text(1500000, 0, '1.5'),
#   Text(2000000, 0, '2'),
#   Text(2500000, 0, '2.5'),
#   Text(3000000, 0, '3'),
#   Text(3500000, 0, '3.5')])

# %%
# creating scatterplot of 'Price in EUR' and 'Width'
scatter_price_width = sns.lmplot(x = 'Price in EUR', y = 'Width', data = mini_boat, scatter_kws={'color': 'purple'})

# setting axis labels
plt.xlabel('Price in Euros by Million')
plt.ylabel('Width by Meters')
plt.xticks([0, 500000, 1000000, 1500000, 2000000, 2500000, 3000000, 3500000], ['0', '0.5', '1', '1.5', '2', '2.5', '3', '3.5'])
# Out:
# /Users/paigepearson/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ([<matplotlib.axis.XTick at 0x174084350>,
#   <matplotlib.axis.XTick at 0x17406a4d0>,
#   <matplotlib.axis.XTick at 0x1740aca10>,
#   <matplotlib.axis.XTick at 0x1740ae950>,
#   <matplotlib.axis.XTick at 0x1740b47d0>,
#   <matplotlib.axis.XTick at 0x1740b6cd0>,
#   <matplotlib.axis.XTick at 0x1740ae290>,
#   <matplotlib.axis.XTick at 0x1740c9610>],
#  [Text(0, 0, '0'),
#   Text(500000, 0, '0.5'),
#   Text(1000000, 0, '1'),
#   Text(1500000, 0, '1.5'),
#   Text(2000000, 0, '2'),
#   Text(2500000, 0, '2.5'),
#   Text(3000000, 0, '3'),
#   Text(3500000, 0, '3.5')])

# %%
# creating scatterplot of 'Price in EUR' and 'Year Built'
scatter_price_year = sns.lmplot(x = 'Price in EUR', y = 'Year Built', data = mini_boat, scatter_kws={'color': 'purple'})

# setting axis labels
plt.xlabel('Price in Euros by Million')
plt.ylabel('Year Built')
plt.xticks([0, 500000, 1000000, 1500000, 2000000, 2500000, 3000000, 3500000], ['0', '0.5', '1', '1.5', '2', '2.5', '3', '3.5'])
# Out:
# /Users/paigepearson/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ([<matplotlib.axis.XTick at 0x1740faa90>,
#   <matplotlib.axis.XTick at 0x16a467c10>,
#   <matplotlib.axis.XTick at 0x17519f150>,
#   <matplotlib.axis.XTick at 0x1751c49d0>,
#   <matplotlib.axis.XTick at 0x1751c4f10>,
#   <matplotlib.axis.XTick at 0x1751d5010>,
#   <matplotlib.axis.XTick at 0x1751d7c10>,
#   <matplotlib.axis.XTick at 0x1751df190>],
#  [Text(0, 0, '0'),
#   Text(500000, 0, '0.5'),
#   Text(1000000, 0, '1'),
#   Text(1500000, 0, '1.5'),
#   Text(2000000, 0, '2'),
#   Text(2500000, 0, '2.5'),
#   Text(3000000, 0, '3'),
#   Text(3500000, 0, '3.5')])

# %%
# creating histogram of the 'Price in EUR' variable
#sns.histplot(mini_boat['Price in EUR'], bins = 20, kde = True)

# Set the bin size and range
bin_size = 10000
x_range = range(0, 350001, bin_size)

# Create the histogram
sns.histplot(mini_boat['Price in EUR'], bins=x_range, kde=True, color='navy', edgecolor='white')

# Set x-axis label
plt.xlabel('Price in Euros')

# Set x-axis ticks every 20,000 with shortened "20" labels
x_ticks = range(0, 350001, 50000)
x_tick_labels = [str(x // 1000) + 'k' for x in x_ticks]

# Adjust the x-axis tick positions and labels
plt.xticks(x_ticks, x_tick_labels)

# Set x-axis range limit
plt.xlim(0, 350000)
# Out:
# (0.0, 350000.0)

# %%
mini_boat.describe()
# Out:
#        Price in EUR   Year Built       Length        Width        Views
# count  8.736000e+03  8736.000000  8736.000000  8736.000000  8736.000000
# mean   2.197779e+05  2006.397779    11.205205     3.474837   135.440705
# std    3.469220e+05    12.559613     4.693041     1.038355    98.486114
# min    3.300000e+03  1956.000000     1.150000     0.010000    13.000000
# 25%    4.500000e+04  2000.000000     7.507500     2.550000    69.000000
# 50%    9.500000e+04  2008.000000    10.360000     3.350000   106.000000
# 75%    2.431500e+05  2018.000000    13.800000     4.220000   167.000000
# max    3.111528e+06  2021.000000    29.600000     7.060000   613.000000

# %%
# Set the bin size and range
bin_size = 1
x_range = range(0, 101, bin_size)

# Create the histogram
sns.histplot(mini_boat['Length'], bins=x_range, kde=True, color='navy', edgecolor='white')

# Set x-axis label
plt.xlabel('Length in Meters')

# Set x-axis ticks every 5
x_ticks = range(0, 101, 5)
x_tick_labels = [str(x) for x in x_ticks]

# Adjust the x-axis tick positions and labels
plt.xticks(x_ticks, x_tick_labels)

# Set x-axis range limit
plt.xlim(0, 35)
plt.ylim(0, 950)
# Out:
# (0.0, 950.0)

# %%
# creating histogram of the 'Width' variable

# Set the bin size and range
bin_size = 1
x_range = range(0, 31, bin_size)

# Create the histogram
sns.histplot(mini_boat['Width'], bins=x_range, kde=True, color='navy', edgecolor='white')

# Set x-axis label
plt.xlabel('Width in Meters')

# Set x-axis ticks every 1
x_ticks = range(0, 8, 1)

# Adjust the x-axis tick positions
plt.xticks(x_ticks)

# Set x-axis range limit
plt.xlim(0, 8)
# Out:
# (0.0, 8.0)
